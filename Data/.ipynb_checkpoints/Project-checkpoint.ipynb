# %%
#importing 
import pandas as pd
from pathlib import Path
import numpy as np
import os

# %%
#importing csv data
csvluxury = Path("../Luxury_goods.csv")
csvbigmac1 = Path("../big_mac_index/big-mac-full-index.csv")
csvpriceindex = Path("../price_index_by_city/PropertyPriceIndexByCity_2021.csv")
path = 'C:\\Users\\Jacks\\Desktop\\New Fintech\\Craig-theG-ng\\Data\\price_index_by_city'
os.chdir(path)

dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['.ipynb_checkpoints', 'PropertyPriceIndexByCity_2009.xlsx', 'PropertyPriceIndexByCity_2010.csv', 'PropertyPriceIndexByCity_2011.csv', 'PropertyPriceIndexByCity_2012.csv', 'PropertyPriceIndexByCity_2013.csv', 'PropertyPriceIndexByCity_2014.csv', 'PropertyPriceIndexByCity_2015.csv', 'PropertyPriceIndexByCity_2016.csv', 'PropertyPriceIndexByCity_2017.csv', 'PropertyPriceIndexByCity_2018.csv', 'PropertyPriceIndexByCity_2019.csv', 'PropertyPriceIndexByCity_2020.csv', 'PropertyPriceIndexByCity_2021.csv', '~$PropertyPriceIndexByCity_2009.xlsx']

# %%
#reading in all price index csv 
#reading in the excel data and concating it to sheet_df
#setting ID name using l/rstrip
#adding ID name to a new column and name the column "Year"
#append all filtered data to df
df = pd.DataFrame()
print("Loop Progress:")
for file in dir_list:
    if file.endswith('.csv'):
        print("Adding to Dataframe",file)
        sheet_df = pd.concat([pd.read_csv(file)], ignore_index = True)
        id =file.lstrip('PropertyPriceIndexByCity_').rstrip('.csv')
        print(id)
        sheet_df['Year'] = id
        df = df.append(sheet_df, ignore_index = True)
        print("complete:",file)
# Out:
# Loop Progress:
# Adding to Dataframe PropertyPriceIndexByCity_2010.csv
# 2010
# complete: PropertyPriceIndexByCity_2010.csv
# Adding to Dataframe PropertyPriceIndexByCity_2011.csv
# 2011
# complete: PropertyPriceIndexByCity_2011.csv
# Adding to Dataframe PropertyPriceIndexByCity_2012.csv
# 2012
# complete: PropertyPriceIndexByCity_2012.csv
# Adding to Dataframe PropertyPriceIndexByCity_2013.csv
# 2013
# complete: PropertyPriceIndexByCity_2013.csv
# Adding to Dataframe PropertyPriceIndexByCity_2014.csv
# 2014
# complete: PropertyPriceIndexByCity_2014.csv
# Adding to Dataframe PropertyPriceIndexByCity_2015.csv
# 2015
# complete: PropertyPriceIndexByCity_2015.csv
# Adding to Dataframe PropertyPriceIndexByCity_2016.csv
# 2016
# complete: PropertyPriceIndexByCity_2016.csv
# Adding to Dataframe PropertyPriceIndexByCity_2017.csv
# 2017
# complete: PropertyPriceIndexByCity_2017.csv
# Adding to Dataframe PropertyPriceIndexByCity_2018.csv
# 2018
# complete: PropertyPriceIndexByCity_2018.csv
# Adding to Dataframe PropertyPriceIndexByCity_2019.csv
# 2019
# complete: PropertyPriceIndexByCity_2019.csv
# Adding to Dataframe PropertyPriceIndexByCity_2020.csv
# 2020
# complete: PropertyPriceIndexByCity_2020.csv
# Adding to Dataframe PropertyPriceIndexByCity_2021.csv
# 2021
# complete: PropertyPriceIndexByCity_2021.csv

# %%
# df[["Year","City", "Price To Income Ratio", "Mortgage As A Percentage Of Income", "Affordability Index"]]
# df[["city","state","country"]] = df["City"].str.split(",", expand = True)
# df.replace(to_replace=[None], value=np.nan, inplace=True)
# df.loc[df['country'].isnull(),'country'] = df['state']
# # df = df[["country","Price To Income Ratio", "Mortgage As A Percentage Of Income", "Affordability Index"]].groupby("country").mean()
# df = df.drop(columns = ["City", "city", "state"])
AUS_price = df.groupby(["country","Year"]).mean()
AUS_price
# Out:
#                 Price To Income Ratio  Mortgage As A Percentage Of Income  \
# country   Year
# Australia 2010              11.433504                          132.866581
#           2011              10.059972                          107.936040
#           2012               9.960000                          103.409347
#           2013               9.717722                          103.040806
#           2014               9.776632                          100.709835
#           2015               9.849980                          102.318996
#           2016              10.896448                          109.765405
#           2017              11.314475                          124.273969
#           2018              10.010364                           94.557636
#           2019              11.001204                          109.765886
#           2020              10.567891                          106.229478
#           2021              10.289701                           97.421833
#
#                 Affordability Index
# country   Year
# Australia 2010             1.592393
#           2011             1.972308
#           2012             1.920339
#           2013             2.084194
#           2014             2.112107
#           2015             2.242275
#           2016             1.904247
#           2017             2.111595
#           2018             2.258036
#           2019             2.022977
#           2020             2.013265
#           2021             1.965578

# %%
# #reading in price index for 2021
# data_priceindex = pd.read_csv(csvpriceindex)
# data_priceindex = data_priceindex[["City", "Price To Income Ratio", "Mortgage As A Percentage Of Income", "Affordability Index"]]
# #splitting city into 3 new columns, city, state, country. filling country NanN value with the values in the state column then groupby 
# data_priceindex[["city","state","country"]] = data_priceindex["City"].str.split(",", expand = True)
# data_priceindex.replace(to_replace=[None], value=np.nan, inplace=True)
# data_priceindex.loc[data_priceindex['country'].isnull(),'country'] = data_priceindex['state']
# data_priceindex = data_priceindex[["country","Price To Income Ratio", "Mortgage As A Percentage Of Income", "Affordability Index"]].groupby("country").mean()
# data_priceindex

# %%
# Data cleaning

# %%
## Reading and cleaning data for luxury goods

# %%
#reading data
data = pd.read_csv(csvluxury)

#slice data to get the Date and Price
data_1 = data.iloc[:, [0,1]]

#separate dates into month and year column
data_1[["month", "year"]] = data_1["Date"].str.split(" ", expand = True)

#setting price as float and removing comma
data_2 = data_1.drop(columns = ["Date", "month"])
data_2['Price'] = data_2['Price'].str.replace(',','')
data_2['Price'] = data_2['Price'].astype(float, errors = 'raise')

#groupby years for the average yearly price and dropping years that does not have 12 months of data
data_grp = data_2.groupby("year").mean().drop(index = ["09", "22"])
luxury_data = data_grp.reset_index()
luxury_data.plot(title = "S&P Global Luxury Index from 10 - 21")
luxury_data = luxury_data.rename(columns = 
                                 {"10" : "2010"}
                                )
luxury_data
# Out:
# C:\Users\Jacks\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    year        Price
# 0    10  1166.026667
# 1    11  1501.445000
# 2    12  1599.625833
# 3    13  2009.355000
# 4    14  2240.652500
# 5    15  2117.350000
# 6    16  1910.015000
# 7    17  2341.828333
# 8    18  2693.004167
# 9    19  2683.002500
# 10   20  2948.280000
# 11   21  4561.890000

# %%
# Reading and cleaning data for big mac index

# %%
#reading in data
bigmac = pd.read_csv(csvbigmac1)
bigmac = bigmac.iloc[:, [0,3,6]]
bigmac.head()

#slicing date column by dates, country and calculating average prices
bigmac[["year", "month", "day"]] = bigmac["date"].str.split("-", expand = True)
bigmac = bigmac.drop(columns = ["date", "month", "day"]).set_index("name")

#average yearly price of big mac in Australia
AUS = bigmac.loc["Australia"]
AUS = AUS.groupby("year").mean()
# AUS.plot(title = "Australian big mac index from 2000 to 2021")

#average yearly price of big mac in US
US = bigmac.loc["United States"]
US = US.groupby("year").mean()

#Average yearly price of big mac in Japan
JPY = bigmac.loc["Japan"]
JPY = JPY.groupby("year").mean()

#Average yearly price of big mac in Singapore
SIN = bigmac.loc["Singapore"]
SIN = SIN.groupby("year").mean()

##Average yearly price of big mac in Switzerland
SWI = bigmac.loc["Switzerland"]
SWI = SWI.groupby("year").mean()

#Average yearly price of big mac in Argentina
ARG = bigmac.loc["Argentina"]
ARG = ARG.groupby("year").mean()

#Average yearly price of big mac in RUSSIA
RUS = bigmac.loc["Russia"]
RUS = RUS.groupby("year").mean()

#Average yearly price of big mac in BRAZIL
BRA = bigmac.loc["Brazil"]
BRA = BRA.groupby("year").mean()

#Average yearly price of big mac in Mexico
MEX = bigmac.loc["Mexico"]
MEX = MEX.groupby("year").mean()

#Average yearly price of big mac in CANADA
CAN = bigmac.loc["Canada"]
CAN = CAN.groupby("year").mean()

# %%
new = pd.concat([AUS, US, JPY, SIN, SWI ,ARG, RUS, BRA, MEX, CAN], axis = 1, join = "outer")
name = ["AUS", "US", "JPY", "SIN", "SWI","ARG", "RUS", "BRA", "MEX", "CAN"]
new.columns = name
bigmac_filtered = new.tail(12)
bigmac_filtered
# Out:
#            AUS        US       JPY       SIN       SWI       ARG       RUS  \
# year
# 2010  3.907394  3.656667  3.583153  3.133431  6.244555  2.700889  2.335617
# 2011  4.943724  4.065000  4.083456  3.653535  8.063016  4.839685  2.702459
# 2012  4.808358  4.262360  4.125596  3.623886  6.683625  4.398785  2.419321
# 2013  4.760160  4.462031  3.355309  3.665655  6.921945  3.848926  2.533474
# 2014  4.643844  4.709583  3.309003  3.696714  6.984353  2.802453  2.588535
# 2015  4.120485  4.790000  3.063643  3.482590  7.182832  3.158583  1.623886
# 2016  4.024196  4.985000  3.292700  3.642138  6.517461  2.868772  1.788627
# 2017  4.401568  5.180000  3.309118  3.978507  6.545913  3.796962  2.214559
# 2018  4.610776  5.395000  3.468772  4.331613  6.654508  3.332768  2.191490
# 2019  4.306075  5.660000  3.591086  4.269117  6.581851  2.436454  1.844238
# 2020  4.514798  5.690000  3.589841  4.315781  6.809426  3.178060  2.055061
# 2021  4.888851  5.655000  3.643472  4.372750  7.167418  3.846425  2.038234
#
#            BRA       MEX       CAN
# year
# 2010  4.832747  2.500419  3.987171
# 2011  6.162429  2.741897  5.000793
# 2012  5.307322  2.703552  4.827628
# 2013  5.464298  2.881850  5.327380
# 2014  5.551326  3.011370  5.132137
# 2015  4.744673  3.231496  4.587777
# 2016  4.068007  2.592022  4.374477
# 2017  5.109756  2.493268  4.582750
# 2018  4.757308  2.571920  5.162245
# 2019  4.570974  2.591939  5.120404
# 2020  4.359043  2.442619  5.129163
# 2021  4.170759  2.931551  5.300689
